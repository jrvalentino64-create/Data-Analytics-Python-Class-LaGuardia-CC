# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/mtcars.csv')

# %%
df.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df.tail() #mpg is miles per hour, cyl is cylinders, hp is horse power, wt is weight
# Out:
#         Unnamed: 0   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  \
# 27    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.9   1   1     5
# 28  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1     5
# 29    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.5   0   1     5
# 30   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0   1     5
# 31      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.6   1   1     4
#
#     carb
# 27     2
# 28     4
# 29     6
# 30     8
# 31     2

# %%
df.dtypes
# Out:
# Unnamed: 0     object
# mpg           float64
# cyl             int64
# disp          float64
# hp              int64
# drat          float64
# wt            float64
# qsec          float64
# vs              int64
# am              int64
# gear            int64
# carb            int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs',
#        'am', 'gear', 'carb'],
#       dtype='object')

# %%
df.rename(columns={'Unnamed: 0':'Vehicle Types', 'mpg':'Miles_Per_Hour','cyl': 'Cylinders', 'hp': 'Horse_Power','wt': 'Weight'})
# Out:
#           Vehicle Types  Miles_Per_Hour  Cylinders   disp  Horse_Power  drat  \
# 0             Mazda RX4            21.0          6  160.0          110  3.90
# 1         Mazda RX4 Wag            21.0          6  160.0          110  3.90
# 2            Datsun 710            22.8          4  108.0           93  3.85
# 3        Hornet 4 Drive            21.4          6  258.0          110  3.08
# 4     Hornet Sportabout            18.7          8  360.0          175  3.15
# 5               Valiant            18.1          6  225.0          105  2.76
# 6            Duster 360            14.3          8  360.0          245  3.21
# 7             Merc 240D            24.4          4  146.7           62  3.69
# 8              Merc 230            22.8          4  140.8           95  3.92
# 9              Merc 280            19.2          6  167.6          123  3.92
# 10            Merc 280C            17.8          6  167.6          123  3.92
# ...

# %%
subset_columns = df.rename(columns={'Unnamed: 0':'Vehicle Types', 'mpg':'Miles_Per_Hour','cyl': 'Cylinders', 'hp': 'Horse_Power','wt': 'Weight'})

# %%
subset_columns[['Miles_Per_Hour','Horse_Power','Weight','Cylinders']]
# Out:
#     Miles_Per_Hour  Horse_Power  Weight  Cylinders
# 0             21.0          110   2.620          6
# 1             21.0          110   2.875          6
# 2             22.8           93   2.320          4
# 3             21.4          110   3.215          6
# 4             18.7          175   3.440          8
# 5             18.1          105   3.460          6
# 6             14.3          245   3.570          8
# 7             24.4           62   3.190          4
# 8             22.8           95   3.150          4
# 9             19.2          123   3.440          6
# 10            17.8          123   3.440          6
# 11            16.4          180   4.070          8
# 12            17.3          180   3.730          8
# 13            15.2          180   3.780          8
# 14            10.4          205   5.250          8
# 15            10.4          215   5.424          8
# 16            14.7          230   5.345          8
# ...
